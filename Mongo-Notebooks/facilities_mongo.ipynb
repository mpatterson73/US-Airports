# %%
import numpy as np
import pandas as pd
from pymongo import MongoClient

# %%
df = pd.read_csv("../../Clean-Data/facilities_clean.tsv", sep='\t', engine='python')

# %%
df.head()
# Out:
#   site_number           type location_id effective_date region state  \
# 0    50009.*A        AIRPORT         ADK     2020-02-27    AAL    AK
# 1   50016.1*A        AIRPORT         AKK     2020-02-27    AAL    AK
# 2    50017.*A        AIRPORT         Z13     2020-02-27    AAL    AK
# 3   50017.1*C  SEAPLANE BASE         KKI     2020-02-27    AAL    AK
# 4    50020.*A        AIRPORT         AKI     2020-02-27    AAL    AK
#
#   state_name          county         city facility_name  ... beacon_color  \
# 0     ALASKA  ALEUTIANS WEST  ADAK ISLAND          ADAK  ...           CG
# 1     ALASKA   KODIAK ISLAND       AKHIOK        AKHIOK  ...          NaN
# 2     ALASKA          BETHEL     AKIACHAK      AKIACHAK  ...           CG
# 3     ALASKA          BETHEL     AKIACHAK      AKIACHAK  ...          NaN
# 4     ALASKA          BETHEL        AKIAK         AKIAK  ...           CG
#
#   non_commercial_landing_fee medical_use operations_commercial  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19636 entries, 0 to 19635
# Data columns (total 63 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   site_number                 19636 non-null  object
#  1   type                        19636 non-null  object
#  2   location_id                 19636 non-null  object
#  3   effective_date              19636 non-null  object
#  4   region                      19636 non-null  object
#  5   state                       19636 non-null  object
#  6   state_name                  19636 non-null  object
#  7   county                      19636 non-null  object
#  8   city                        19636 non-null  object
#  9   facility_name               19636 non-null  object
#  10  ownership                   19636 non-null  object
#  11  use                         19636 non-null  object
#  12  owner                       19541 non-null  object
# ...

# %%
facilities_list = df.to_dict(orient='records')

# %%
facilities_list[0]
# Out:
# {'site_number': '50009.*A',
#  'type': 'AIRPORT',
#  'location_id': 'ADK',
#  'effective_date': '2020-02-27',
#  'region': 'AAL',
#  'state': 'AK',
#  'state_name': 'ALASKA',
#  'county': 'ALEUTIANS WEST',
#  'city': 'ADAK ISLAND',
#  'facility_name': 'ADAK',
#  'ownership': 'PU',
#  'use': 'PU',
#  'owner': 'ALASKA DOT&PF SOUTHCOAST REGION',
#  'owner_address': '1500 ANTON LARSON',
#  'owner_csz': 'KODIAK, AK 99615-2506',
#  'owner_phone': '907-465-1784',
#  'manager': 'INNOCENT DUSHKIN',
#  'manager_address': 'P O BOX 1952',
#  'manager_csz': 'ADAK, AK 99546',
#  'manager_phone': '907-592-8026',
#  'latitude': 51.883582055555564,
#  'longitude': -176.64247991666667,
#  'elevation': 19,
#  'magnetic_variation': '07E',
#  'magnetic_variation_year': 2000.0,
#  'traffic_pattern_altitude': nan,
#  'chart_name': 'W ALEUTIAN ISLS',
#  'distance_from_cbd': 0.0,
#  'direction_from_cbd': 'W',
#  'boundary_artcc_id': 'ZAN',
#  'boundary_artcc_name': 'ANCHORAGE',
# ...

# %%
client = MongoClient('mongodb://localhost:27017/')

# %%
db = client.us_airports

# %%
facilities_coll = db.facilities

# %%
results = facilities_coll.insert_many(facilities_list)

# %%
len(results.inserted_ids)
# Out:
# 19636

# %%
client.close()
