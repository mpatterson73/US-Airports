# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Airports/regions.csv')
df.head(20)
# Out:
#         id    code local_code                    name continent iso_country  \
# 0   302811   AD-02         02                 Canillo        EU          AD
# 1   302812   AD-03         03                  Encamp        EU          AD
# 2   302813   AD-04         04              La Massana        EU          AD
# 3   302814   AD-05         05                  Ordino        EU          AD
# 4   302815   AD-06         06     Sant Julià de Lòria        EU          AD
# 5   302816   AD-07         07        Andorra la Vella        EU          AD
# 6   302817   AD-08         08      Escaldes-Engordany        EU          AD
# 7   302818  AD-U-A        U-A            (unassigned)        EU          AD
# 8   302819   AE-AJ         AJ           Ajman Emirate        AS          AE
# 9   302820   AE-AZ         AZ       Abu Dhabi Emirate        AS          AE
# 10  302821   AE-DU         DU           Dubai Emirate        AS          AE
# ...

# %%
df = df[df['iso_country'] == 'US']
df
# Out:
#           id    code local_code                  name continent iso_country  \
# 3674  306076   US-AK         AK                Alaska       NaN          US
# 3675  306077   US-AL         AL               Alabama       NaN          US
# 3676  306078   US-AR         AR              Arkansas       NaN          US
# 3677  306079   US-AZ         AZ               Arizona       NaN          US
# 3678  306080   US-CA         CA            California       NaN          US
# 3679  306081   US-CO         CO              Colorado       NaN          US
# 3680  306082   US-CT         CT           Connecticut       NaN          US
# 3681  306083   US-DC         DC  District of Columbia       NaN          US
# 3682  306084   US-DE         DE              Delaware       NaN          US
# 3683  306085   US-FL         FL               Florida       NaN          US
# 3684  306086   US-GA         GA               Georgia       NaN          US
# ...

# %%
df.drop(columns=['code', 'continent' ,'iso_country', 'keywords'], inplace=True)
df
# Out:
#           id local_code                  name  \
# 3674  306076         AK                Alaska
# 3675  306077         AL               Alabama
# 3676  306078         AR              Arkansas
# 3677  306079         AZ               Arizona
# 3678  306080         CA            California
# 3679  306081         CO              Colorado
# 3680  306082         CT           Connecticut
# 3681  306083         DC  District of Columbia
# 3682  306084         DE              Delaware
# 3683  306085         FL               Florida
# 3684  306086         GA               Georgia
# 3685  306087         HI                Hawaii
# 3686  306088         IA                  Iowa
# 3687  306089         ID                 Idaho
# 3688  306090         IL              Illinois
# 3689  306091         IN               Indiana
# 3690  306092         KS                Kansas
# 3691  306093         KY              Kentucky
# 3692  306094         LA             Louisiana
# ...

# %%
df.columns = (['id', 'abbr', 'state', 'wikipedia'])

# %%
df.to_csv('Clean-Data/states_clean.csv')
