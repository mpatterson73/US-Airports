# %%
import numpy as np
import pandas as pd
import re

# %%
cols_to_keep = ['SiteNumber', 'State', 'RunwayID', 'RunwayLength', 'RunwayWidth', 'RunwaySurfaceTypeCondition', 'RunwaySurfaceTreatment', 'EdgeLightsIntensity', 'BaseEndID', 'BaseEndTrueAlignment', 'BaseEndILSType', 'BaseEndRightTrafficPattern', 'BaseEndMarkingsType', 'BaseEndMarkingsCondition', 'BaseEndPhysicalLatitude', 'BaseEndPhysicalLatitudeS', 'BaseEndPhysicalLongitude', 'BaseEndPhysicalLongitudeS', 'BaseEndPhysicalElevation', 'BaseEndCrossingHeight', 'BaseEndGlidePathAngle', 'BaseEndDisplacedLength', 'BaseEndVASI', 'BaseEndCenterlineLights', 'BaseEndTouchdownLights', 'BaseEndObjectDescription', 'BaseEndObjectHeight', 'ReciprocalEndID', 'ReciprocalEndTrueAlignment', 'ReciprocalEndILSType', 'ReciprocalEndRightTrafficPattern', 'ReciprocalEndMarkingsType', 'ReciprocalEndMarkingsCondition', 'ReciprocalEndPhysicalLatitude', 'ReciprocalEndPhysicalLatitudeS', 'ReciprocalEndPhysicalLongitude', 'ReciprocalEndPhysicalLongitudeS', 'ReciprocalEndPhysicalElevation', 'ReciprocalEndCrossingHeight', 'ReciprocalEndGlidePathAngle', 'ReciprocalEndDisplacedLength', 'ReciprocalEndVASI', 'ReciprocalEndCenterlineLights', 'ReciprocalEndTouchdownLights', 'ReciprocalEndObjectDescription', 'ReciprocalEndObjectHeight', 'RunwayWeightBearingCapacitySW', 'RunwayWeightBearingCapacityDW', 'RunwayWeightBearingCapacityDT', 'RunwayWeightBearingCapacityDDT', 'BaseEndTakeOffRunAvailableTORA', 'BaseEndTakeOffDistanceAvailableTODA', 'BaseEndAcltStopDistanceAvailableASDA', 'BaseEndLandingDistanceAvailableLDA', 'ReciprocalEndTakeOffRunAvailableTORA', 'ReciprocalEndTakeOffDistanceAvailableTODA', 'ReciprocalEndAcltStopDistanceAvailableASDA', 'ReciprocalEndLandingDistanceAvailableLDA']

# %%
df = pd.read_csv('orig_runways_faa.tsv', sep='\t', index_col=False, usecols=cols_to_keep, engine='python')
pd.set_option('display.max_columns', 140)
pd.set_option('display.max_rows', 110)
df.head()
# Out:
#   SiteNumber State RunwayID  RunwayLength  RunwayWidth  \
# 0   00103.*A    AL   '17/35          2900           80
# 1   00106.*A    AL   '05/23          2644          112
# 2   00108.*A    AL   '01/19          2002           60
# 3   00108.*A    AL   '07/25          1104           60
# 4   00110.*A    AL   '16/34          5000           75
#
#   RunwaySurfaceTypeCondition RunwaySurfaceTreatment EdgeLightsIntensity  \
# 0                ASPH-CONC-F                   AFSC                 MED
# 1                     TURF-G                    NaN                 NaN
# 2                     TURF-G                    NaN                 NaN
# 3                     TURF-G                    NaN                 NaN
# 4                     ASPH-G                    NaN                 MED
#
#   BaseEndID  BaseEndTrueAlignment BaseEndILSType BaseEndRightTrafficPattern  \
# 0       '17                 172.0            NaN                          N
# 1       '05                  49.0            NaN                        NaN
# 2       '01                   NaN            NaN                        NaN
# 3       '07                   NaN            NaN                        NaN
# 4       '16                 157.0            NaN                          N
#
#   BaseEndMarkingsType BaseEndMarkingsCondition BaseEndPhysicalLatitude  \
# 0                 BSC                        F          31-36-14.9900N
# 1                NSTD                      NaN          34-12-53.1000N
# 2                 NaN                      NaN                     NaN
# 3                 NaN                      NaN                     NaN
# 4                 NPI                        G          33-11-02.8099N
#
#   BaseEndPhysicalLatitudeS BaseEndPhysicalLongitude BaseEndPhysicalLongitudeS  \
# 0             113774.9900N          085-14-20.2000W              306860.2000W
# 1             123173.1000N          087-09-41.2200W              313781.2200W
# 2                      NaN                      NaN                       NaN
# 3                      NaN                      NaN                       NaN
# 4             119462.8099N          086-47-10.9568W              312430.9568W
#
#    BaseEndPhysicalElevation  BaseEndCrossingHeight  BaseEndGlidePathAngle  \
# 0                     463.1                    NaN                    NaN
# 1                     786.0                    NaN                    NaN
# 2                       NaN                    NaN                    NaN
# 3                       NaN                    NaN                    NaN
# 4                     572.7                   57.0                    3.5
#
#    BaseEndDisplacedLength BaseEndVASI BaseEndCenterlineLights  \
# 0                   300.0         NaN                     NaN
# 1                     NaN         NaN                     NaN
# 2                   400.0         NaN                     NaN
# 3                     NaN         NaN                     NaN
# 4                     NaN         P4L                     NaN
#
#   BaseEndTouchdownLights BaseEndObjectDescription  BaseEndObjectHeight  \
# 0                    NaN                    PLINE                 36.0
# 1                    NaN                    TREES                 32.0
# 2                    NaN                    TREES                 23.0
# 3                    NaN                      NaN                  NaN
# 4                    NaN                     BLDG                 70.0
#
#   ReciprocalEndID  ReciprocalEndTrueAlignment ReciprocalEndILSType  \
# 0             '35                       352.0                  NaN
# 1             '23                       229.0                  NaN
# 2             '19                         NaN                  NaN
# 3             '25                         NaN                  NaN
# 4             '34                       337.0                  NaN
#
#   ReciprocalEndRightTrafficPattern ReciprocalEndMarkingsType  \
# 0                                N                       BSC
# 1                              NaN                      NSTD
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                                Y                       NPI
#
#   ReciprocalEndMarkingsCondition ReciprocalEndPhysicalLatitude  \
# 0                              F                31-35-46.5600N
# 1                            NaN                34-13-10.3200N
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                              G                33-10-17.1992N
#
#   ReciprocalEndPhysicalLatitudeS ReciprocalEndPhysicalLongitude  \
# 0                   113746.5600N                085-14-15.6200W
# 1                   123190.3200N                087-09-17.5200W
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                   119417.1992N                086-46-48.1798W
#
#   ReciprocalEndPhysicalLongitudeS  ReciprocalEndPhysicalElevation  \
# 0                    306855.6200W                           462.8
# 1                    313757.5200W                           776.0
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                    312408.1798W                           585.6
#
#    ReciprocalEndCrossingHeight  ReciprocalEndGlidePathAngle  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                         44.0                          4.0
#
#    ReciprocalEndDisplacedLength ReciprocalEndVASI  \
# 0                           NaN               NaN
# 1                           NaN               NaN
# 2                         600.0               NaN
# 3                           NaN               NaN
# 4                           NaN               P4L
#
#   ReciprocalEndCenterlineLights ReciprocalEndTouchdownLights  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#   ReciprocalEndObjectDescription  ReciprocalEndObjectHeight  \
# 0                           TREE                       28.0
# 1                          TREES                       25.0
# 2                          PLINE                       25.0
# 3                            NaN                        NaN
# 4                           BLDG                       60.0
#
#    RunwayWeightBearingCapacitySW  RunwayWeightBearingCapacityDW  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                           16.0                            NaN
#
#    RunwayWeightBearingCapacityDT  RunwayWeightBearingCapacityDDT  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    BaseEndTakeOffRunAvailableTORA  BaseEndTakeOffDistanceAvailableTODA  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                             NaN                                  NaN
# 3                             NaN                                  NaN
# 4                             NaN                                  NaN
#
#    BaseEndAcltStopDistanceAvailableASDA  BaseEndLandingDistanceAvailableLDA  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#    ReciprocalEndTakeOffRunAvailableTORA  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    ReciprocalEndTakeOffDistanceAvailableTODA  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ReciprocalEndAcltStopDistanceAvailableASDA  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    ReciprocalEndLandingDistanceAvailableLDA
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN

# %%
df.shape
# Out:
# (23439, 58)

# %%
col_list = df.columns

# %%
df.columns = [re.sub(r'(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|(?<=[A-Z])(?=ID)', '_', x) 
              for x in col_list]

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
df.columns
# Out:
# Index(['site_number', 'state', 'runway_id', 'runway_length', 'runway_width',
#        'runway_surface_type_condition', 'runway_surface_treatment',
#        'edge_lights_intensity', 'base_end_id', 'base_end_true_alignment',
#        'base_end_ils_type', 'base_end_right_traffic_pattern',
#        'base_end_markings_type', 'base_end_markings_condition',
#        'base_end_physical_latitude', 'base_end_physical_latitude_s',
#        'base_end_physical_longitude', 'base_end_physical_longitude_s',
#        'base_end_physical_elevation', 'base_end_crossing_height',
#        'base_end_glide_path_angle', 'base_end_displaced_length',
#        'base_end_vasi', 'base_end_centerline_lights',
#        'base_end_touchdown_lights', 'base_end_object_description',
#        'base_end_object_height', 'reciprocal_end_id',
#        'reciprocal_end_true_alignment', 'reciprocal_end_ils_type',
#        'reciprocal_end_right_traffic_pattern', 'reciprocal_end_markings_type',
#        'reciprocal_end_markings_condition', 'reciprocal_end_physical_latitude',
#        'reciprocal_end_physical_latitude_s',
#        'reciprocal_end_physical_longitude',
#        'reciprocal_end_physical_longitude_s',
#        'reciprocal_end_physical_elevation', 'reciprocal_end_crossing_height',
#        'reciprocal_end_glide_path_angle', 'reciprocal_end_displaced_length',
#        'reciprocal_end_vasi', 'reciprocal_end_centerline_lights',
#        'reciprocal_end_touchdown_lights', 'reciprocal_end_object_description',
#        'reciprocal_end_object_height', 'runway_weight_bearing_capacity_sw',
#        'runway_weight_bearing_capacity_dw',
#        'runway_weight_bearing_capacity_dt',
#        'runway_weight_bearing_capacity_ddt',
#        'base_end_take_off_run_available_tora',
#        'base_end_take_off_distance_available_toda',
#        'base_end_aclt_stop_distance_available_asda',
#        'base_end_landing_distance_available_lda',
#        'reciprocal_end_take_off_run_available_tora',
#        'reciprocal_end_take_off_distance_available_toda',
#        'reciprocal_end_aclt_stop_distance_available_asda',
#        'reciprocal_end_landing_distance_available_lda'],
#       dtype='object')

# %%
#col_list = df.columns
df.columns = [re.sub(r'_end', '', col) for col in df.columns]
df.columns = [re.sub(r'reciprocal', 'rcpr', col) for col in df.columns]
df.columns = [re.sub(r'rcpr_id', 'reciprocal_end_id', col) for col in df.columns]
df.columns = [re.sub(r'base_id', 'base_end_id', col) for col in df.columns]
df.columns = [re.sub(r'condition', 'cond', col) for col in df.columns]
df.columns = [re.sub(r'_physical|_description|_traffic|', '', col) for col in df.columns]
df.columns = [re.sub(r'weight_bearing_capacity', 'capacity_lbs', col) for col in df.columns]
df.columns = [re.sub(r'_take_off_run_available|_take_off_distance_available|_aclt_stop_distance_available|_landing_distance_available',
                    '', col) for col in df.columns]

# %%
df.columns
# Out:
# Index(['site_number', 'state', 'runway_id', 'runway_length', 'runway_width',
#        'runway_surface_type_cond', 'runway_surface_treatment',
#        'edge_lights_intensity', 'base_end_id', 'base_true_alignment',
#        'base_ils_type', 'base_right_pattern', 'base_markings_type',
#        'base_markings_cond', 'base_latitude', 'base_latitude_s',
#        'base_longitude', 'base_longitude_s', 'base_elevation',
#        'base_crossing_height', 'base_glide_path_angle',
#        'base_displaced_length', 'base_vasi', 'base_centerline_lights',
#        'base_touchdown_lights', 'base_object', 'base_object_height',
#        'reciprocal_end_id', 'rcpr_true_alignment', 'rcpr_ils_type',
#        'rcpr_right_pattern', 'rcpr_markings_type', 'rcpr_markings_cond',
#        'rcpr_latitude', 'rcpr_latitude_s', 'rcpr_longitude',
#        'rcpr_longitude_s', 'rcpr_elevation', 'rcpr_crossing_height',
#        'rcpr_glide_path_angle', 'rcpr_displaced_length', 'rcpr_vasi',
#        'rcpr_centerline_lights', 'rcpr_touchdown_lights', 'rcpr_object',
#        'rcpr_object_height', 'runway_capacity_lbs_sw',
#        'runway_capacity_lbs_dw', 'runway_capacity_lbs_dt',
#        'runway_capacity_lbs_ddt', 'base_tora', 'base_toda', 'base_asda',
#        'base_lda', 'rcpr_tora', 'rcpr_toda', 'rcpr_asda', 'rcpr_lda'],
#       dtype='object')

# %%
df[['base_end_id', 'reciprocal_end_id']] = df[['base_end_id', 'reciprocal_end_id']].applymap(lambda x: x[1:])
df.head()
# Out:
#       site_number state runway_id  runway_length  runway_width  \
# 0        00103.*A    AL    '17/35           2900            80
# 1        00106.*A    AL    '05/23           2644           112
# 2        00108.*A    AL    '01/19           2002            60
# 3        00108.*A    AL    '07/25           1104            60
# 4        00110.*A    AL    '16/34           5000            75
# ...           ...   ...       ...            ...           ...
# 23434   55027.3*H    VI       'H1             50            50
# 23435    55030.*A    VI    '10/28          10004           150
# 23436   55030.1*C    VI      'E/W           7000           600
# 23437    55045.*H    VI       'H1            100           100
# 23438    55058.*H    VI       'H1             20            16
#
#       runway_surface_type_cond runway_surface_treatment edge_lights_intensity  \
# 0                  ASPH-CONC-F                     AFSC                   MED
# 1                       TURF-G                      NaN                   NaN
# 2                       TURF-G                      NaN                   NaN
# 3                       TURF-G                      NaN                   NaN
# 4                       ASPH-G                      NaN                   MED
# ...                        ...                      ...                   ...
# 23434                     CONC                      NaN                   NaN
# 23435                   ASPH-G                     GRVD                  HIGH
# 23436                    WATER                      NaN                   NaN
# 23437                     TURF                      NaN                   NaN
# 23438                     WOOD                      NaN                  PERI
#
#       base_end_id  base_true_alignment base_ils_type base_right_pattern  \
# 0              17                172.0           NaN                  N
# 1              05                 49.0           NaN                NaN
# 2              01                  NaN           NaN                NaN
# 3              07                  NaN           NaN                NaN
# 4              16                157.0           NaN                  N
# ...           ...                  ...           ...                ...
# 23434          H1                  NaN           NaN                NaN
# 23435          10                 84.0           ILS                  Y
# 23436           E                  NaN           NaN                  N
# 23437          H1                  NaN           NaN                NaN
# 23438          H1                  NaN           NaN                NaN
#
#       base_markings_type base_markings_cond   base_latitude base_latitude_s  \
# 0                    BSC                  F  31-36-14.9900N    113774.9900N
# 1                   NSTD                NaN  34-12-53.1000N    123173.1000N
# 2                    NaN                NaN             NaN             NaN
# 3                    NaN                NaN             NaN             NaN
# 4                    NPI                  G  33-11-02.8099N    119462.8099N
# ...                  ...                ...             ...             ...
# 23434                NaN                NaN             NaN             NaN
# 23435                PIR                  G  17-42-00.2120N    063720.2120N
# 23436                NaN                NaN             NaN             NaN
# 23437                NaN                NaN             NaN             NaN
# 23438                NaN                NaN  18-19-11.8380N    065951.8380N
#
#         base_longitude base_longitude_s  base_elevation  base_crossing_height  \
# 0      085-14-20.2000W     306860.2000W           463.1                   NaN
# 1      087-09-41.2200W     313781.2200W           786.0                   NaN
# 2                  NaN              NaN             NaN                   NaN
# 3                  NaN              NaN             NaN                   NaN
# 4      086-47-10.9568W     312430.9568W           572.7                  57.0
# ...                ...              ...             ...                   ...
# 23434              NaN              NaN             NaN                   NaN
# 23435  064-48-58.4450W     233338.4450W            73.7                  73.0
# 23436              NaN              NaN             0.0                   NaN
# 23437              NaN              NaN             NaN                   NaN
# 23438  064-55-19.5190W     233719.5190W            20.0                   NaN
#
#        base_glide_path_angle  base_displaced_length base_vasi  \
# 0                        NaN                  300.0       NaN
# 1                        NaN                    NaN       NaN
# 2                        NaN                  400.0       NaN
# 3                        NaN                    NaN       NaN
# 4                        3.5                    NaN       P4L
# ...                      ...                    ...       ...
# 23434                    NaN                    NaN       NaN
# 23435                    3.0                    NaN       P4L
# 23436                    NaN                    NaN       NaN
# 23437                    NaN                    NaN       NaN
# 23438                    NaN                    NaN       NaN
#
#       base_centerline_lights base_touchdown_lights base_object  \
# 0                        NaN                   NaN       PLINE
# 1                        NaN                   NaN       TREES
# 2                        NaN                   NaN       TREES
# 3                        NaN                   NaN         NaN
# 4                        NaN                   NaN        BLDG
# ...                      ...                   ...         ...
# 23434                    NaN                   NaN         NaN
# 23435                    NaN                   NaN         NaN
# 23436                    NaN                   NaN         NaN
# 23437                    NaN                   NaN         NaN
# 23438                    NaN                   NaN         NaN
#
#        base_object_height reciprocal_end_id  rcpr_true_alignment  \
# 0                    36.0                35                352.0
# 1                    32.0                23                229.0
# 2                    23.0                19                  NaN
# 3                     NaN                25                  NaN
# 4                    70.0                34                337.0
# ...                   ...               ...                  ...
# 23434                 NaN                                    NaN
# 23435                 NaN                28                264.0
# 23436                 NaN                 W                  NaN
# 23437                 NaN                                    NaN
# 23438                 NaN                                    NaN
#
#       rcpr_ils_type rcpr_right_pattern rcpr_markings_type rcpr_markings_cond  \
# 0               NaN                  N                BSC                  F
# 1               NaN                NaN               NSTD                NaN
# 2               NaN                NaN                NaN                NaN
# 3               NaN                NaN                NaN                NaN
# 4               NaN                  Y                NPI                  G
# ...             ...                ...                ...                ...
# 23434           NaN                NaN                NaN                NaN
# 23435           NaN                  N                NPI                  G
# 23436           NaN                  N                NaN                NaN
# 23437           NaN                NaN                NaN                NaN
# 23438           NaN                NaN                NaN                NaN
#
#         rcpr_latitude rcpr_latitude_s   rcpr_longitude rcpr_longitude_s  \
# 0      31-35-46.5600N    113746.5600N  085-14-15.6200W     306855.6200W
# 1      34-13-10.3200N    123190.3200N  087-09-17.5200W     313757.5200W
# 2                 NaN             NaN              NaN              NaN
# 3                 NaN             NaN              NaN              NaN
# 4      33-10-17.1992N    119417.1992N  086-46-48.1798W     312408.1798W
# ...               ...             ...              ...              ...
# 23434             NaN             NaN              NaN              NaN
# 23435  17-42-10.6200N    063730.6200N  064-47-15.5440W     233235.5440W
# 23436             NaN             NaN              NaN              NaN
# 23437             NaN             NaN              NaN              NaN
# 23438             NaN             NaN              NaN              NaN
#
#        rcpr_elevation  rcpr_crossing_height  rcpr_glide_path_angle  \
# 0               462.8                   NaN                    NaN
# 1               776.0                   NaN                    NaN
# 2                 NaN                   NaN                    NaN
# 3                 NaN                   NaN                    NaN
# 4               585.6                  44.0                    4.0
# ...               ...                   ...                    ...
# 23434             NaN                   NaN                    NaN
# 23435            22.5                  80.0                    3.0
# 23436             0.0                   NaN                    NaN
# 23437             NaN                   NaN                    NaN
# 23438             NaN                   NaN                    NaN
#
#        rcpr_displaced_length rcpr_vasi rcpr_centerline_lights  \
# 0                        NaN       NaN                    NaN
# 1                        NaN       NaN                    NaN
# 2                      600.0       NaN                    NaN
# 3                        NaN       NaN                    NaN
# 4                        NaN       P4L                    NaN
# ...                      ...       ...                    ...
# 23434                    NaN       NaN                    NaN
# 23435                 1006.0       P4L                    NaN
# 23436                    NaN       NaN                    NaN
# 23437                    NaN       NaN                    NaN
# 23438                    NaN       NaN                    NaN
#
#       rcpr_touchdown_lights rcpr_object  rcpr_object_height  \
# 0                       NaN        TREE                28.0
# 1                       NaN       TREES                25.0
# 2                       NaN       PLINE                25.0
# 3                       NaN         NaN                 NaN
# 4                       NaN        BLDG                60.0
# ...                     ...         ...                 ...
# 23434                   NaN         NaN                 NaN
# 23435                   NaN        BLDG               217.0
# 23436                   NaN         NaN                 NaN
# 23437                   NaN         NaN                 NaN
# 23438                   NaN         NaN                 NaN
#
#        runway_capacity_lbs_sw  runway_capacity_lbs_dw  runway_capacity_lbs_dt  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                        16.0                     NaN                     NaN
# ...                       ...                     ...                     ...
# 23434                     NaN                     NaN                     NaN
# 23435                   100.0                   175.0                   300.0
# 23436                     NaN                     NaN                     NaN
# 23437                     NaN                     NaN                     NaN
# 23438                     NaN                     NaN                     NaN
#
#        runway_capacity_lbs_ddt  base_tora  base_toda  base_asda  base_lda  \
# 0                          NaN        NaN        NaN        NaN       NaN
# 1                          NaN        NaN        NaN        NaN       NaN
# 2                          NaN        NaN        NaN        NaN       NaN
# 3                          NaN        NaN        NaN        NaN       NaN
# 4                          NaN        NaN        NaN        NaN       NaN
# ...                        ...        ...        ...        ...       ...
# 23434                      NaN        NaN        NaN        NaN       NaN
# 23435                      NaN    10004.0    10004.0     9003.0    9003.0
# 23436                      NaN        NaN        NaN        NaN       NaN
# 23437                      NaN        NaN        NaN        NaN       NaN
# 23438                      NaN        NaN        NaN        NaN       NaN
#
#        rcpr_tora  rcpr_toda  rcpr_asda  rcpr_lda
# 0            NaN        NaN        NaN       NaN
# 1            NaN        NaN        NaN       NaN
# 2            NaN        NaN        NaN       NaN
# 3            NaN        NaN        NaN       NaN
# 4            NaN        NaN        NaN       NaN
# ...          ...        ...        ...       ...
# 23434        NaN        NaN        NaN       NaN
# 23435    10004.0    10004.0    10004.0    9003.0
# 23436        NaN        NaN        NaN       NaN
# 23437        NaN        NaN        NaN       NaN
# 23438        NaN        NaN        NaN       NaN
#
# [23439 rows x 58 columns]

# %%
bool_cols = ['base_right_pattern', 'base_centerline_lights', 'base_touchdown_lights', 'rcpr_right_pattern', 'rcpr_centerline_lights', 'rcpr_touchdown_lights']

# %%
for col in bool_cols:
    df[col] = df[col].map({'Y': True, 'N': False})
#df[[bool_cols]].map({'Y': True, 'N': False})

# %%
df

# %%
df.to_csv('../Clean-Data/facilities-clean.tsv', sep='\t')
