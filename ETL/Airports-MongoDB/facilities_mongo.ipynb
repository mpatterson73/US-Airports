# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Clean-Data/facilities_clean.tsv", sep='\t', index_col=0, engine='python')

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19636 entries, 50009.*A to 27905.*A
# Data columns (total 62 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   type                        19636 non-null  object
#  1   location_id                 19636 non-null  object
#  2   effective_date              19636 non-null  object
#  3   region                      19636 non-null  object
#  4   state                       19636 non-null  object
#  5   state_name                  19636 non-null  object
#  6   county                      19636 non-null  object
#  7   city                        19636 non-null  object
#  8   facility_name               19636 non-null  object
#  9   ownership                   19636 non-null  object
#  10  use                         19636 non-null  object
#  11  owner                       19541 non-null  object
#  12  owner_address               19289 non-null  object
# ...

# %%
df['location_id'].value_counts()
# Out:
# ME70    1
# T42     1
# 6II5    1
# 0C0     1
# 0L4     1
#        ..
# AK75    1
# 34NJ    1
# E38     1
# CO74    1
# 42IA    1
# Name: location_id, Length: 19636, dtype: int64

# %%
mongo_dict = df.to_dict(orient='recirds')

# %%
mongo_dict
# Out:
# [{'type': 'AIRPORT',
#   'location_id': 'ADK',
#   'effective_date': '2020-02-27',
#   'region': 'AAL',
#   'state': 'AK',
#   'state_name': 'ALASKA',
#   'county': 'ALEUTIANS WEST',
#   'city': 'ADAK ISLAND',
#   'facility_name': 'ADAK',
#   'ownership': 'PU',
#   'use': 'PU',
#   'owner': 'ALASKA DOT&PF SOUTHCOAST REGION',
#   'owner_address': '1500 ANTON LARSON',
#   'owner_csz': 'KODIAK, AK 99615-2506',
#   'owner_phone': '907-465-1784',
#   'manager': 'INNOCENT DUSHKIN',
#   'manager_address': 'P O BOX 1952',
#   'manager_csz': 'ADAK, AK 99546',
#   'manager_phone': '907-592-8026',
#   'latitude': 51.883582055555564,
#   'longitude': -176.64247991666667,
#   'elevation': 19,
#   'magnetic_variation': '07E',
#   'magnetic_variation_year': 2000.0,
#   'traffic_pattern_altitude': nan,
#   'chart_name': 'W ALEUTIAN ISLS',
#   'distance_from_cbd': 0.0,
#   'direction_from_cbd': 'W',
#   'boundary_artcc_id': 'ZAN',
#   'boundary_artcc_name': 'ANCHORAGE',
# ...

# %%
# Out:
#                 type location_id effective_date region state state_name  \
# site_number
# 06646.2*A    AIRPORT        SN69     2020-02-27    ACE    KS     KANSAS
# 06648.4*A    AIRPORT        5KS3     2020-02-27    ACE    KS     KANSAS
# 06648.1*A    AIRPORT         8K2     2020-02-27    ACE    KS     KANSAS
# 06648.11*A   AIRPORT        SN70     2020-02-27    ACE    KS     KANSAS
# 06648.61*A   AIRPORT        SN72     2020-02-27    ACE    KS     KANSAS
#
#                county     city facility_name ownership  ... beacon_color  \
# site_number                                             ...
# 06646.2*A     BOURBON  HAMMOND      EMMERSON        PR  ...          NaN
# 06648.4*A      HARPER   HARPER        DEWEZE        PR  ...          NaN
# 06648.1*A      HARPER   HARPER   HARPER MUNI        PU  ...          NaN
# 06648.11*A     HARPER   HARPER        KAYPOD        PR  ...          NaN
# 06648.61*A   ANDERSON   HARRIS  GRAHAM FARMS        PR  ...          NaN
#
# ...

# %%
data.to_dict(orient="records")
# Out:
# [{'type': 'AIRPORT',
#   'location_id': 'SN69',
#   'effective_date': '2020-02-27',
#   'region': 'ACE',
#   'state': 'KS',
#   'state_name': 'KANSAS',
#   'county': 'BOURBON',
#   'city': 'HAMMOND',
#   'facility_name': 'EMMERSON',
#   'ownership': 'PR',
#   'use': 'PR',
#   'owner': 'JAMES EMERSON',
#   'owner_address': '1829 255TH ST.',
#   'owner_csz': 'FORT SCOTT, KS 66701',
#   'owner_phone': '316-857-4499',
#   'manager': 'FRED EMERSON',
#   'manager_address': '1856 255TH ST.',
#   'manager_csz': 'FORT SCOTT, KS 66701',
#   'manager_phone': '316-857-4498',
#   'latitude': 37.931426388888895,
#   'longitude': -94.64273611111109,
#   'elevation': 860,
#   'magnetic_variation': '05E',
#   'magnetic_variation_year': 1985.0,
#   'traffic_pattern_altitude': nan,
#   'chart_name': 'KANSAS CITY',
#   'distance_from_cbd': 3.0,
#   'direction_from_cbd': 'E',
#   'boundary_artcc_id': 'ZKC',
#   'boundary_artcc_name': 'KANSAS CITY',
#   'responsible_artcc_id': 'ZKC',
# ...
