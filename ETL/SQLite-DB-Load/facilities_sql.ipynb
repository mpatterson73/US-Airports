# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Clean-Data/facilities_clean.tsv", sep='\t', index_col=0, engine='python')

# %%
df.head()
# Out:
#   site_number           type location_id effective_date region state  \
# 0    50009.*A        AIRPORT         ADK     2020-02-27    AAL    AK
# 1   50016.1*A        AIRPORT         AKK     2020-02-27    AAL    AK
# 2    50017.*A        AIRPORT         Z13     2020-02-27    AAL    AK
# 3   50017.1*C  SEAPLANE BASE         KKI     2020-02-27    AAL    AK
# 4    50020.*A        AIRPORT         AKI     2020-02-27    AAL    AK
#
#   state_name          county         city facility_name  ...  \
# 0     ALASKA  ALEUTIANS WEST  ADAK ISLAND          ADAK  ...
# 1     ALASKA   KODIAK ISLAND       AKHIOK        AKHIOK  ...
# 2     ALASKA          BETHEL     AKIACHAK      AKIACHAK  ...
# 3     ALASKA          BETHEL     AKIACHAK      AKIACHAK  ...
# 4     ALASKA          BETHEL        AKIAK         AKIAK  ...
#
#   military_operational ultralights operations_commercial operations_commuter  \
# 0                  0.0         0.0                 104.0                 NaN
# ...
