# %% [markdown]
# ### Countries CSV
# * shorten wikipedia_link col
# * add NA to north american countries' continent column

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Airports/countries.csv', keep_default_na=False)
df
# Out:
#          id code                           name continent  \
# 0    302672   AD                        Andorra        EU
# 1    302618   AE           United Arab Emirates        AS
# 2    302619   AF                    Afghanistan        AS
# 3    302722   AG            Antigua and Barbuda        NA
# 4    302723   AI                       Anguilla        NA
# ..      ...  ...                            ...       ...
# 242  302609   YT                        Mayotte        AF
# 243  302610   ZA                   South Africa        AF
# 244  302611   ZM                         Zambia        AF
# 245  302612   ZW                       Zimbabwe        AF
# 246  302613   ZZ  Unknown or unassigned country        AF
#
#                                         wikipedia_link  \
# 0                https://en.wikipedia.org/wiki/Andorra
# 1    https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2            https://en.wikipedia.org/wiki/Afghanistan
# ...

# %%
df.shape
# Out:
# (247, 6)

# %%
df['continent'].isnull().value_counts()
# Out:
# False    247
# Name: continent, dtype: int64

# %%
df.rename(columns={'wikipedia_link': 'wikipedia'}, inplace=True)
df
# Out:
#          id code                           name continent  \
# 0    302672   AD                        Andorra        EU
# 1    302618   AE           United Arab Emirates        AS
# 2    302619   AF                    Afghanistan        AS
# 3    302722   AG            Antigua and Barbuda        NA
# 4    302723   AI                       Anguilla        NA
# ..      ...  ...                            ...       ...
# 242  302609   YT                        Mayotte        AF
# 243  302610   ZA                   South Africa        AF
# 244  302611   ZM                         Zambia        AF
# 245  302612   ZW                       Zimbabwe        AF
# 246  302613   ZZ  Unknown or unassigned country        AF
#
#                                              wikipedia  \
# 0                https://en.wikipedia.org/wiki/Andorra
# 1    https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2            https://en.wikipedia.org/wiki/Afghanistan
# ...

# %%
df[df['continent'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, code, name, continent, wikipedia, keywords]
# Index: []

# %%
df['continent'].fillna('NA', inplace=True)
df
# Out:
#          id code                           name continent  \
# 0    302672   AD                        Andorra        EU
# 1    302618   AE           United Arab Emirates        AS
# 2    302619   AF                    Afghanistan        AS
# 3    302722   AG            Antigua and Barbuda        NA
# 4    302723   AI                       Anguilla        NA
# ..      ...  ...                            ...       ...
# 242  302609   YT                        Mayotte        AF
# 243  302610   ZA                   South Africa        AF
# 244  302611   ZM                         Zambia        AF
# 245  302612   ZW                       Zimbabwe        AF
# 246  302613   ZZ  Unknown or unassigned country        AF
#
#                                              wikipedia  \
# 0                https://en.wikipedia.org/wiki/Andorra
# 1    https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2            https://en.wikipedia.org/wiki/Afghanistan
# ...

# %%
df['continent'].isnull().value_counts()
# Out:
# False    247
# Name: continent, dtype: int64

# %%
df
# Out:
#          id code                           name continent  \
# 0    302672   AD                        Andorra        EU
# 1    302618   AE           United Arab Emirates        AS
# 2    302619   AF                    Afghanistan        AS
# 3    302722   AG            Antigua and Barbuda        NA
# 4    302723   AI                       Anguilla        NA
# ..      ...  ...                            ...       ...
# 242  302609   YT                        Mayotte        AF
# 243  302610   ZA                   South Africa        AF
# 244  302611   ZM                         Zambia        AF
# 245  302612   ZW                       Zimbabwe        AF
# 246  302613   ZZ  Unknown or unassigned country        AF
#
#                                              wikipedia  \
# 0                https://en.wikipedia.org/wiki/Andorra
# 1    https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2            https://en.wikipedia.org/wiki/Afghanistan
# ...

# %%
df.to_csv('Clean-Data/countries_clean.csv')
