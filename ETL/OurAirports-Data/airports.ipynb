# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Airports/airports.csv')
df.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.949200    -151.695999         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# ...

# %%
df = df[df['iso_country'] == 'US']
df
# Out:
#            id ident           type                                name  \
# 0        6523   00A       heliport                   Total Rf Heliport
# 1      323361  00AA  small_airport                Aero B Ranch Airport
# 2        6524  00AK  small_airport                        Lowell Field
# 3        6525  00AL  small_airport                        Epps Airpark
# 4        6526  00AR         closed  Newport Hospital & Clinic Heliport
# ...       ...   ...            ...                                 ...
# 55377   26365   Z91  small_airport                 Birch Creek Airport
# 55378   26366   Z92  small_airport              Harsens Island Airport
# 55379   26367   Z93  small_airport             Copper Center 2 Airport
# 55380   26368   Z95  small_airport                     Cibecue Airport
# 55702   26369   ZNC  small_airport                        Nyac Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# ...

# %%
len(df['iso_region'].value_counts())
# Out:
# 52

# %%
df['iso_region'].value_counts()
# Out:
# US-TX     2284
# US-CA     1097
# US-FL      978
# US-PA      920
# US-IL      904
# US-AK      832
# US-OH      806
# US-IN      703
# US-NY      668
# US-WI      627
# US-LA      603
# US-MO      585
# US-WA      581
# US-MN      577
# US-MI      553
# US-OK      547
# US-GA      521
# US-VA      508
# US-CO      507
# US-OR      499
# US-NC      472
# US-KS      446
# US-NJ      445
# US-AR      408
# US-AL      368
# US-TN      359
# US-AZ      359
# US-IA      343
# US-MT      335
# US-ND      323
# US-ID      318
# US-NE      311
# US-MS      282
# US-KY      259
# US-MA      258
# US-MD      257
# US-SC      219
# US-ME      219
# US-SD      211
# US-NM      200
# US-NH      179
# US-UT      170
# US-NV      166
# US-CT      164
# US-WV      140
# US-WY      127
# US-VT      102
# US-HI       64
# US-DE       58
# US-RI       35
# US-DC       21
# US-U-A       2
# Name: iso_region, dtype: int64

# %%
df['iso_region'].replace(to_replace='US-U-A', value='US-NV', inplace=True)

# %%
df['iso_region'].value_counts()
# Out:
# US-TX    2284
# US-CA    1097
# US-FL     978
# US-PA     920
# US-IL     904
# US-AK     832
# US-OH     806
# US-IN     703
# US-NY     668
# US-WI     627
# US-LA     603
# US-MO     585
# US-WA     581
# US-MN     577
# US-MI     553
# US-OK     547
# US-GA     521
# US-VA     508
# US-CO     507
# US-OR     499
# US-NC     472
# US-KS     446
# US-NJ     445
# US-AR     408
# US-AL     368
# US-TN     359
# US-AZ     359
# US-IA     343
# US-MT     335
# US-ND     323
# US-ID     318
# US-NE     311
# US-MS     282
# US-KY     259
# US-MA     258
# US-MD     257
# US-ME     219
# US-SC     219
# US-SD     211
# US-NM     200
# US-NH     179
# US-UT     170
# US-NV     168
# US-CT     164
# US-WV     140
# US-WY     127
# US-VT     102
# US-HI      64
# US-DE      58
# US-RI      35
# US-DC      21
# Name: iso_region, dtype: int64

# %%
df.drop(columns=['id', 'continent', 'iso_country'], inplace=True)

# %%
df.columns = ['ident', 'type', 'name', 'latitude', 'longitude', 'elevation_ft', 'state', 'municipality', 'service',
              'gps_code', 'iata_code', 'local_code', 'website', 'wikipedia', 'keywords']
df.head()
# Out:
#   ident           type                                name   latitude  \
# 0   00A       heliport                   Total Rf Heliport  40.070801
# 1  00AA  small_airport                Aero B Ranch Airport  38.704022
# 2  00AK  small_airport                        Lowell Field  59.949200
# 3  00AL  small_airport                        Epps Airpark  34.864799
# 4  00AR         closed  Newport Hospital & Clinic Heliport  35.608700
#
#     longitude  elevation_ft  state  municipality service gps_code iata_code  \
# 0  -74.933601          11.0  US-PA      Bensalem      no      00A       NaN
# 1 -101.473911        3435.0  US-KS         Leoti      no     00AA       NaN
# 2 -151.695999         450.0  US-AK  Anchor Point      no     00AK       NaN
# 3  -86.770302         820.0  US-AL       Harvest      no     00AL       NaN
# 4  -91.254898         237.0  US-AR       Newport      no      NaN       NaN
#
#   local_code website wikipedia keywords
# 0        00A     NaN       NaN      NaN
# ...

# %%
df['state'] = df['state'].apply(lambda x: x[3:])

# %%
df.head()
# Out:
#   ident           type                                name   latitude  \
# 0   00A       heliport                   Total Rf Heliport  40.070801
# 1  00AA  small_airport                Aero B Ranch Airport  38.704022
# 2  00AK  small_airport                        Lowell Field  59.949200
# 3  00AL  small_airport                        Epps Airpark  34.864799
# 4  00AR         closed  Newport Hospital & Clinic Heliport  35.608700
#
#     longitude  elevation_ft state  municipality service gps_code iata_code  \
# 0  -74.933601          11.0    PA      Bensalem      no      00A       NaN
# 1 -101.473911        3435.0    KS         Leoti      no     00AA       NaN
# 2 -151.695999         450.0    AK  Anchor Point      no     00AK       NaN
# 3  -86.770302         820.0    AL       Harvest      no     00AL       NaN
# 4  -91.254898         237.0    AR       Newport      no      NaN       NaN
#
#   local_code website wikipedia keywords
# 0        00A     NaN       NaN      NaN
# ...

# %%
df['service'] = df['service'].map({'yes': True, 'no': False})
df.head(25)
# Out:
#    ident           type                                name   latitude  \
# 0    00A       heliport                   Total Rf Heliport  40.070801
# 1   00AA  small_airport                Aero B Ranch Airport  38.704022
# 2   00AK  small_airport                        Lowell Field  59.949200
# 3   00AL  small_airport                        Epps Airpark  34.864799
# 4   00AR         closed  Newport Hospital & Clinic Heliport  35.608700
# 5   00AS  small_airport                      Fulton Airport  34.942803
# 6   00AZ  small_airport                      Cordes Airport  34.305599
# 7   00CA  small_airport             Goldstone /Gts/ Airport  35.350498
# 8   00CL  small_airport                 Williams Ag Airport  39.427188
# 9   00CN       heliport     Kitchen Creek Helibase Heliport  32.727374
# 10  00CO         closed                          Cass Field  40.622202
# 11  00FA  small_airport                 Grass Patch Airport  28.645500
# ...

# %%
df.to_csv('Clean-Data/airports_clean.csv')
